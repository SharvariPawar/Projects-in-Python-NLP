# %%
'''Artificial Intelligence is used in context with NLP. Areas of application of AI:
1.	CV - Computer vision i.e intelligence related to human vision. Example
	a)	Driverless car
	b)	Face recognition
	c)	Object detection
2.	NLP - Intelligence related to Text and speech. NLP is not technology and is area of application.
 .	Alexa
	a)	Chatbot
	b)	Sentiment analysis
	c)	Spam email detection in gmail
3.	Robotics
4.	Few more as well
'''
# Out:
# run
# run
# better
# better
# wolv
# studi
# studi

# %%
# NLP
from nltk.stem.porter import PorterStemmer
ps = PorterStemmer()
print(ps.stem("runs"))
print(ps.stem("running"))
print(ps.stem("betterment"))
print(ps.stem("better"))
print(ps.stem("wolves"))
print(ps.stem("studying"))
print(ps.stem("study"))
# Out:
# run
# run
# better
# better
# wolv
# studi
# studi

# %%
# Lemmatization
import nltk
# To be executed only once
nltk.download('wordnet') 
from nltk.stem import WordNetLemmatizer 
lemmatizer = WordNetLemmatizer() 
print(lemmatizer.lemmatize("wolves"))
print(lemmatizer.lemmatize("resumes", pos="n")) 
print(lemmatizer.lemmatize("better", pos="a")) # will show good instead of better i.e. root word
print(lemmatizer.lemmatize("good", pos="a")) # will show good instead of better i.e. root word
# Out:
# wolf
# resume
# good
# good
# [nltk_data] Downloading package wordnet to /home/labsuser/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
print(lemmatizer.lemmatize("scathing")) 
print(lemmatizer.lemmatize("criticize"))
# Out:
# scathing
# criticize

# %%
print(lemmatizer.lemmatize("scorching")) 
print(lemmatizer.lemmatize("burning"))
# Out:
# scorching
# burning

# %%
####################################### Spam Detector Model - Case Study #######################################
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import MultinomialNB

# %%
df = pd.read_csv('/home/labsuser/Datasets/spam.csv', encoding='ISO-8859-1')
df
# Out:
#         v1                                                 v2 Unnamed: 2  \
# 0      ham  Go until jurong point, crazy.. Available only ...        NaN
# 1      ham                      Ok lar... Joking wif u oni...        NaN
# 2     spam  Free entry in 2 a wkly comp to win FA Cup fina...        NaN
# 3      ham  U dun say so early hor... U c already then say...        NaN
# 4      ham  Nah I don't think he goes to usf, he lives aro...        NaN
# ...    ...                                                ...        ...
# 5567  spam  This is the 2nd time we have tried 2 contact u...        NaN
# 5568   ham              Will Ì_ b going to esplanade fr home?        NaN
# 5569   ham  Pity, * was in mood for that. So...any other s...        NaN
# 5570   ham  The guy did some bitching but I acted like i'd...        NaN
# 5571   ham                         Rofl. Its true to its name        NaN
#
#      Unnamed: 3 Unnamed: 4
# 0           NaN        NaN
# 1           NaN        NaN
# ...

# %%
# drop unnecessary columns
df = df.drop(["Unnamed: 2", "Unnamed: 3", "Unnamed: 4"], axis=1)

# rename columns to something better
df.columns = ['labels', 'data']
df
# Out:
#      labels                                               data
# 0       ham  Go until jurong point, crazy.. Available only ...
# 1       ham                      Ok lar... Joking wif u oni...
# 2      spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3       ham  U dun say so early hor... U c already then say...
# 4       ham  Nah I don't think he goes to usf, he lives aro...
# ...     ...                                                ...
# 5567   spam  This is the 2nd time we have tried 2 contact u...
# 5568    ham              Will Ì_ b going to esplanade fr home?
# 5569    ham  Pity, * was in mood for that. So...any other s...
# 5570    ham  The guy did some bitching but I acted like i'd...
# 5571    ham                         Rofl. Its true to its name
#
# [5572 rows x 2 columns]

# %%
# create binary labels
df['b_labels'] = df['labels'].map({'ham': 0, 'spam': 1})

# %%
Y= df['b_labels']

# %%
df.head(10)
# Out:
#   labels                                               data  b_labels
# 0    ham  Go until jurong point, crazy.. Available only ...         0
# 1    ham                      Ok lar... Joking wif u oni...         0
# 2   spam  Free entry in 2 a wkly comp to win FA Cup fina...         1
# 3    ham  U dun say so early hor... U c already then say...         0
# 4    ham  Nah I don't think he goes to usf, he lives aro...         0
# 5   spam  FreeMsg Hey there darling it's been 3 week's n...         1
# 6    ham  Even my brother is not like to speak with me. ...         0
# 7    ham  As per your request 'Melle Melle (Oru Minnamin...         0
# 8   spam  WINNER!! As a valued network customer you have...         1
# 9   spam  Had your mobile 11 months or more? U R entitle...         1

# %%
count_vectorizer = CountVectorizer(decode_error='ignore')
X = count_vectorizer.fit_transform(df['data'])

# %%
print(X)
# Out:
#   (0, 3550)	1
#   (0, 8030)	1
#   (0, 4350)	1
#   (0, 5920)	1
#   (0, 2327)	1
#   (0, 1303)	1
#   (0, 5537)	1
#   (0, 4087)	1
#   (0, 1751)	1
#   (0, 3634)	1
#   (0, 8489)	1
#   (0, 4476)	1
#   (0, 1749)	1
#   (0, 2048)	1
#   (0, 7645)	1
#   (0, 3594)	1
#   (0, 1069)	1
#   (0, 8267)	1
#   (1, 5504)	1
#   (1, 4512)	1
#   (1, 4318)	1
#   (1, 8392)	1
#   (1, 5533)	1
#   (2, 4087)	1
#   (2, 3358)	1
#   :	:
#   (5570, 4218)	1
#   (5570, 8313)	1
#   (5570, 1084)	1
#   (5570, 4615)	1
#   (5570, 7039)	1
#   (5570, 3308)	1
#   (5570, 7627)	1
#   (5570, 1438)	1
#   (5570, 5334)	1
#   (5570, 2592)	1
#   (5570, 8065)	1
#   (5570, 1778)	1
#   (5570, 7049)	1
#   (5570, 2892)	1
#   (5570, 3470)	1
#   (5570, 1786)	1
#   (5570, 3687)	1
#   (5570, 4161)	1
#   (5570, 903)	1
#   (5570, 1546)	1
#   (5571, 7756)	1
#   (5571, 5244)	1
#   (5571, 4225)	2
#   (5571, 7885)	1
#   (5571, 6505)	1

# %%
# print(count_vectorizer.get_feature_names()) # list of words

# %%
print(len(count_vectorizer.get_feature_names()))
# Out:
# 8672

# %%
# split up the data
Xtrain, Xtest, Ytrain, Ytest = train_test_split(X, Y, test_size=0.2)

# create the model, train it, print scores
model = MultinomialNB()
model.fit(Xtrain, Ytrain)
# Out:
# MultinomialNB(alpha=1.0, class_prior=None, fit_prior=True)

# %%
print("train score:", model.score(Xtrain, Ytrain)) # Model is 99% accurate
# Out:
# train score: 0.9939421135292797

# %%
# Predicting on test data
y_pred = model.predict(Xtest)

from sklearn.metrics import confusion_matrix
cm = confusion_matrix(Ytest, y_pred)
print(cm)
# Out:
# [[939  11]
#  [  6 159]]

# %%
sensitivity_score = 159/(159+6)
sensitivity_score
# Out:
# 0.9636363636363636

# %%
# Test with some new data 
comment = "URGENT Free membership"
data = [comment]
vect = count_vectorizer.transform(data).toarray()
my_prediction = model.predict(vect)

if(my_prediction == 0):
     print("Ham")
if(my_prediction == 1):
     print("Spam")
# Out:
# Spam

# %%
# Test with some new data 
comment = "Your request for new telecom connection is under process"
data = [comment]
vect = count_vectorizer.transform(data).toarray()
my_prediction = model.predict(vect)

if(my_prediction == 0):
     print("Ham")
if(my_prediction == 1):
     print("Spam")
# Out:
# Ham

# %%
#word cloud
# !pip install wordcloud
from wordcloud import WordCloud
# visualize the data
def visualize(label):
  words = ''
  for msg in df[df['labels'] == label]['data']:
    msg = msg.lower()
    words += msg + ' '
  wordcloud = WordCloud(width=600, height=400).generate(words)
  plt.imshow(wordcloud)
  plt.axis('off')
  plt.show()

visualize('spam') # word cloud for spam messages
visualize('ham') # word cloud for ham messages

# %%
# sentiment analysis
import nltk
nltk.download('vader_lexicon')

from nltk.sentiment.vader import SentimentIntensityAnalyzer

sid = SentimentIntensityAnalyzer()

a = 'This was a good movie'
print(sid.polarity_scores(a))

a = 'This was the best, most awesome movie EVER MADE!!!'
print(sid.polarity_scores(a))

a = 'This was the worst film to ever disgrace the screen.'
print(sid.polarity_scores(a))
# Out:
# {'neg': 0.0, 'neu': 0.508, 'pos': 0.492, 'compound': 0.4404}
# {'neg': 0.0, 'neu': 0.425, 'pos': 0.575, 'compound': 0.8877}
# {'neg': 0.477, 'neu': 0.523, 'pos': 0.0, 'compound': -0.8074}
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /home/labsuser/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!

# %%
a = 'This was not a good movie'
print(sid.polarity_scores(a))
# Out:
# {'neg': 0.376, 'neu': 0.624, 'pos': 0.0, 'compound': -0.3412}

# %%
# Net Score
print(sid.polarity_scores(a)['pos'] - sid.polarity_scores(a)['neg'])
import numpy as np
(sid.polarity_scores(a)['pos'] - sid.polarity_scores(a)['neg'])/np.where(sid.polarity_scores(a)['pos'].isna(),1,sid.polarity_scores(a)['pos'])
# Out:
# -0.048000000000000015
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-57-15e8ab6040b7> in <module>
#       2 print(sid.polarity_scores(a)['pos'] - sid.polarity_scores(a)['neg'])
#       3 import numpy as np
# ----> 4 (sid.polarity_scores(a)['pos'] - sid.polarity_scores(a)['neg'])/np.where(sid.polarity_scores(a)['pos'].isna(),1,sid.polarity_scores(a)['pos'])
#
# AttributeError: 'float' object has no attribute 'isna'

# %%
a = 'This was not a good and boring movie'
print(sid.polarity_scores(a))
# Out:
# {'neg': 0.257, 'neu': 0.534, 'pos': 0.209, 'compound': -0.1139}

# %%
## lesson 10  - Visualization - IMPORTANT from Project perspective

# %%
list1 = [10,8,17,4]
import matplotlib.pyplot as plt
# %matplotlib inline
plt.plot(list1)

# %%
import pandas as pd
californiahousing = pd.read_csv("/home/labsuser/Datasets/california_housing_test1.csv")
californiahousing.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.05     37.37                  27         3885             661
# 1    -118.30     34.26                  43         1510             310
# 2    -117.81     33.78                  27         3589             507
# 3    -118.36     33.82                  28           67              15
# 4    -119.67     36.33                  19         1241             244
#
#    population  households  median_income  median_house_value
# 0        1537         606         6.6085              344700
# 1         809         277         3.5990              176500
# 2        1484         495         5.7934              270500
# 3          49          11         6.1359              330000
# 4         850         237         2.9375               81700

# %%
plt.plot(californiahousing.loc[0:100,'median_house_value'])
plt.xlabel("Number of Observations")
plt.ylabel("House Value")
plt.title("Houses Price for first 100 observations")
# plt.grid()
plt.show()

# %%
list1 = [1,2,3,4]
list2 = [10,9,3,7]
import matplotlib.pyplot as plt
plt.plot(list1)
plt.plot(list2)
plt.show() # optional

# %%
list1 = [1,2,3,4]
list2 = [10,9,3,7]
plt.plot(list1)
plt.show()
plt.plot(list2)
plt.show()

# %%
plt.plot(californiahousing.iloc[0:10,3],label='# Tot Rooms',color='r',linewidth=1,linestyle='--',marker='*',markeredgewidth=1)
plt.plot(californiahousing.iloc[0:10,4],label='# Bed Rooms',color='g',linewidth=1,linestyle='-.',marker='o',markeredgewidth=1)
plt.grid()
plt.legend()
plt.xlabel("Number of Observations")
plt.ylabel("Number of total and bed rooms")
plt.title("Number of bed and total rooms for first 10 observations")
# Out:
# Text(0.5,1,'Number of bed and total rooms for first 10 observations')

# %%
income = [1000,2222,3434,4466]
expenditure = [343,456,958,1898]
plt.scatter(income,expenditure)

# %%
californiahousing
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0       -122.05     37.37                  27         3885             661
# 1       -118.30     34.26                  43         1510             310
# 2       -117.81     33.78                  27         3589             507
# 3       -118.36     33.82                  28           67              15
# 4       -119.67     36.33                  19         1241             244
# ...         ...       ...                 ...          ...             ...
# 2995    -119.86     34.42                  23         1450             642
# 2996    -118.14     34.06                  27         5257            1082
# 2997    -119.70     36.30                  10          956             201
# 2998    -117.12     34.10                  40           96              14
# 2999    -119.63     34.42                  42         1765             263
#
#       population  households  median_income  median_house_value
# ...

# %%
plt.plot(californiahousing.iloc[1:10,3],label='# of bedroom') # bedroom
plt.plot(californiahousing.iloc[1:10,4],label='# of house hold') # house hold
plt.legend()
plt.xlim(0,15)
plt.ylim(10,4000)
# Out:
# (10, 4000)

# %%
plt.hist(californiahousing.iloc[:,3])
plt.show()

# %%
Web_monday = [319,281,173,272,182,170,342,381,157,366]
plt.plot(Web_monday)
plt.annotate(str(319),xytext=(0,325),xy=(0,319),ha='center')
plt.show()

# %%
plt.plot(Web_monday)
plt.annotate(("Website traffic as 319"),xytext=(0,325),xy=(0,319),ha='left')
plt.show()

# %%
Web_monday = [319,281,173,272,182,170,342,381,157,366]
plt.plot(Web_monday)
plt.annotate(str(319),xytext=(2,350),xy=(0,319),ha='center',arrowprops={'facecolor':'green'}) 
plt.show()

# %%
plt.plot(Web_monday)
plt.annotate(str(319),xytext=(0,319),xy=(0,319),ha='center') 
plt.show()

# %%
Web_monday = [319,281,173,272,182,170,342,381,157,366]
x_axis_data_point = range(len(Web_monday))
x_axis_data_point
# Out:
# range(0, 10)

# %%
plt.plot(Web_monday)
for x,y in zip(x_axis_data_point,Web_monday):
    plt.annotate(str(y),xytext=(x,y),xy=(x,y))
plt.show()

# %%
Web_monday = [319,281,173,272,182,170,342,381,157,366]
Web_tuesday = [371,270,288,161,124,354,354,190,357,370]
import pandas as pd
Website_data = pd.DataFrame({'Web_monday':Web_monday,'Web_tuesday':Web_tuesday})
Website_data
# Out:
#    Web_monday  Web_tuesday
# 0         319          371
# 1         281          270
# 2         173          288
# 3         272          161
# 4         182          124
# 5         170          354
# 6         342          354
# 7         381          190
# 8         157          357
# 9         366          370

# %%
for i in Website_data.columns:
    plt.plot(Website_data[i])
    plt.title("Webtraffic for: " + i)
    plt.show()

# %%
plt.figure(figsize=(10,4))
Web_monday = [319,281,173,272,182,170,342,381,157,366]
Web_tuesday = [371,270,288,161,124,354,354,190,357,370]
plt.scatter(Web_monday,Web_tuesday)

# %%
### pie chart
GDPData = pd.DataFrame({"Countries":["India","US","UK"],"GDP":[3,21,2.5]})
GDPData
# Out:
#   Countries   GDP
# 0     India   3.0
# 1        US  21.0
# 2        UK   2.5

# %%
plt.pie(GDPData.GDP,labels = GDPData.Countries)
plt.show()

# %%
cars = pd.read_csv('/home/labsuser/Datasets/mtcars.csv')
cars
# Out:
#              Unnamed: 0   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  \
# 0             Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1
# 1         Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1
# 2            Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1
# 3        Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0
# 4     Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0
# 5               Valiant  18.1    6  225.0  105  2.76  3.460  20.22   1   0
# 6            Duster 360  14.3    8  360.0  245  3.21  3.570  15.84   0   0
# 7             Merc 240D  24.4    4  146.7   62  3.69  3.190  20.00   1   0
# 8              Merc 230  22.8    4  140.8   95  3.92  3.150  22.90   1   0
# 9              Merc 280  19.2    6  167.6  123  3.92  3.440  18.30   1   0
# 10            Merc 280C  17.8    6  167.6  123  3.92  3.440  18.90   1   0
# ...

# %%
plt.bar(cars.cyl,cars.wt)
# Out:
# <BarContainer object of 32 artists>

# %%
import pandas as pd
hsb = pd.read_excel("/home/labsuser/Datasets/hsb.xlsx")
hsb.head(50)
# Out:
#      id  female  race  ses  schtyp  prog  read  write  math  science  socst
# 0    70       0     4    1       1     1    57     52    41       47     57
# 1   121       1     4    2       1     3    68     59    53       63     61
# 2    86       0     4    3       1     1    44     33    54       58     31
# 3   141       0     4    3       1     3    63     44    47       53     56
# 4   172       0     4    2       1     2    47     52    57       53     61
# 5   113       0     4    2       1     2    44     52    51       63     61
# 6    50       0     3    2       1     1    50     59    42       53     61
# 7    11       0     1    2       1     2    34     46    45       39     36
# 8    84       0     4    2       1     1    63     57    54       58     51
# 9    48       0     3    2       1     2    57     55    52       50     51
# 10   75       0     4    2       1     3    60     46    51       53     61
# ...

# %%
hsb_subset = hsb.iloc[0:10,:]
hsb_subset
# Out:
#     id  female  race  ses  schtyp  prog  read  write  math  science  socst
# 0   70       0     4    1       1     1    57     52    41       47     57
# 1  121       1     4    2       1     3    68     59    53       63     61
# 2   86       0     4    3       1     1    44     33    54       58     31
# 3  141       0     4    3       1     3    63     44    47       53     56
# 4  172       0     4    2       1     2    47     52    57       53     61
# 5  113       0     4    2       1     2    44     52    51       63     61
# 6   50       0     3    2       1     1    50     59    42       53     61
# 7   11       0     1    2       1     2    34     46    45       39     36
# 8   84       0     4    2       1     1    63     57    54       58     51
# 9   48       0     3    2       1     2    57     55    52       50     51

# %%
# Import from project perspective. Single bar plot
plt.bar(hsb_subset.index,hsb_subset.math,tick_label=hsb_subset.id)
# Out:
# <BarContainer object of 10 artists>

# %%
# stacked bar chart
plt.bar(hsb_subset.index,hsb_subset.math,tick_label=hsb_subset.id)
plt.bar(hsb_subset.index,hsb_subset.science,bottom=hsb_subset.math)
# Out:
# <BarContainer object of 10 artists>

# %%
#Create frequency of math and science scores and put that in stacked bar plot – For Assignment
df_math = pd.DataFrame(hsb.groupby(['math']).agg({'math':'count'}))
df_math.columns = ["No_math_students"]
df_math
# Out:
#       No_math_students
# math
# 33                   1
# 35                   1
# 37                   1
# 38                   2
# 39                   6
# 40                  10
# 41                   7
# 42                   7
# 43                   7
# 44                   4
# 45                   8
# 46                   8
# 47                   3
# 48                   5
# 49                  10
# 50                   7
# 51                   8
# 52                   6
# 53                   7
# 54                  10
# 55                   5
# 56                   7
# 57                  13
# 58                   6
# 59                   2
# 60                   5
# 61                   7
# 62                   4
# 63                   5
# 64                   5
# 65                   3
# 66                   4
# 67                   2
# 68                   1
# 69                   2
# 70                   1
# 71                   4
# 72                   3
# ...

# %%
plt.bar(df_math.index,df_math.No_math_students)
# Out:
# <BarContainer object of 40 artists>

# %%
df_science = pd.DataFrame(hsb.groupby(['science']).agg({'science':'count'}))
df_science.columns=["No_Science_students"]
df_science
# Out:
#          No_Science_students
# science
# 26                         1
# 29                         1
# 31                         2
# 33                         2
# 34                         5
# 35                         1
# 36                         4
# 39                        13
# 40                         2
# 42                        12
# 44                        11
# 45                         1
# 46                         1
# 47                        11
# 48                         2
# 49                         2
# 50                        21
# 51                         2
# 53                        15
# 54                         3
# 55                        18
# 56                         2
# 57                         1
# 58                        19
# 59                         1
# 61                        14
# 63                        12
# 64                         1
# 65                         1
# 66                         9
# ...

# %%
Final = pd.concat([df_math,df_science],axis=1)
Final
# Out:
#     No_math_students  No_Science_students
# 26               NaN                  1.0
# 29               NaN                  1.0
# 31               NaN                  2.0
# 33               1.0                  2.0
# 34               NaN                  5.0
# 35               1.0                  1.0
# 36               NaN                  4.0
# 37               1.0                  NaN
# 38               2.0                  NaN
# 39               6.0                 13.0
# 40              10.0                  2.0
# 41               7.0                  NaN
# 42               7.0                 12.0
# 43               7.0                  NaN
# 44               4.0                 11.0
# 45               8.0                  1.0
# 46               8.0                  1.0
# 47               3.0                 11.0
# 48               5.0                  2.0
# 49              10.0                  2.0
# 50               7.0                 21.0
# ...

# %%
Final.No_math_students = Final.No_math_students.fillna(0)
Final.No_Science_students = Final.No_Science_students.fillna(0)
Final
# Out:
#     No_math_students  No_Science_students
# 26               0.0                  1.0
# 29               0.0                  1.0
# 31               0.0                  2.0
# 33               1.0                  2.0
# 34               0.0                  5.0
# 35               1.0                  1.0
# 36               0.0                  4.0
# 37               1.0                  0.0
# 38               2.0                  0.0
# 39               6.0                 13.0
# 40              10.0                  2.0
# 41               7.0                  0.0
# 42               7.0                 12.0
# 43               7.0                  0.0
# 44               4.0                 11.0
# 45               8.0                  1.0
# 46               8.0                  1.0
# 47               3.0                 11.0
# 48               5.0                  2.0
# 49              10.0                  2.0
# 50               7.0                 21.0
# ...

# %%
plt.figure(figsize=(10,10))
plt.bar(Final.index,Final.No_math_students,label='# of students - Math')
plt.bar(Final.index,Final.No_Science_students,bottom=Final.No_math_students,label='# of students - Science')
plt.legend()

# %%
# Activity 1  (Assignment 3- As per SL Lesson)
# use mtcars data from google drive in datasets folder
# 1. make a plot for wt (weight of car) and mpg (average) - Think about appropriate chart
# 2. make a chart for drat (rear axle ratio) and wt - Think about appropriate chart

# %%
# make a plot for wt (weight of car) and mpg (average) 
import pandas as pd
mtcars_data = pd.read_csv("C:/Users/sharv/Documents/Post Graduate Program In Data Science-PurdueSimpliLearn/Course2-Data Science With Python/Datasets/mtcars.csv")
mtcars_data.head()
# Out:
#           Unnamed: 0   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  \
# 0          Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1     4
# 1      Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1     4
# 2         Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1     4
# 3     Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0     3
# 4  Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0     3
#
#    carb
# 0     4
# 1     4
# 2     1
# 3     1
# 4     2

# %%
mtcars_data.dtypes
# Out:
# Unnamed: 0     object
# mpg           float64
# cyl             int64
# disp          float64
# hp              int64
# drat          float64
# wt            float64
# qsec          float64
# vs              int64
# am              int64
# gear            int64
# carb            int64
# dtype: object

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
plt.scatter(mtcars_data['wt'],mtcars_data['mpg'])

# %%
plt.scatter(mtcars_data.loc[:,"wt"],mtcars_data.loc[:,"drat"])
plt.show()
plt.scatter(mtcars_data.loc[:,"wt"],mtcars_data.loc[:,"mpg"])
plt.show()

# %%
# make a chart for drat (rear axle ratio) and wt - Think about appropriate chart
plt.scatter(mtcars_data['wt'],mtcars_data['drat'])

# %%
# Activity 2 - use HSB data to populate the line series for read,write, math, science and socst variables through for loop and dynamic headers
import pandas as pd
hsb = pd.read_excel("C:/Users/sharv/Documents/Post Graduate Program In Data Science-PurdueSimpliLearn/Course2-Data Science With Python/Datasets/hsb.xls",usecols=[6,7,8,9,10])
hsb.columns
for i in hsb.columns:
    plt.plot(hsb[i])
    plt.title("LineSeries for: " + i)
    plt.show()

# %%
subs=['read','write','math','science','socst']
for sub in subs:
    plt.plot(hsb.loc[:,sub])
    plt.title(sub.capitalize() + ' Score')
    plt.xlabel("Student ID")
    plt.ylabel("Marks")
    plt.show()

# %%
# Correlation with seaborn
import pandas as pd
import seaborn as sns
Boston = pd.read_csv('/home/labsuser/Datasets/boston.csv')
Correlation_Boston = Boston.corr()
Correlation_Boston
# Out:
#              crim        zn     indus      chas       nox        rm       age  \
# crim     1.000000 -0.200469  0.406583 -0.055892  0.420972 -0.219247  0.352734
# zn      -0.200469  1.000000 -0.533828 -0.042697 -0.516604  0.311991 -0.569537
# indus    0.406583 -0.533828  1.000000  0.062938  0.763651 -0.391676  0.644779
# chas    -0.055892 -0.042697  0.062938  1.000000  0.091203  0.091251  0.086518
# nox      0.420972 -0.516604  0.763651  0.091203  1.000000 -0.302188  0.731470
# rm      -0.219247  0.311991 -0.391676  0.091251 -0.302188  1.000000 -0.240265
# age      0.352734 -0.569537  0.644779  0.086518  0.731470 -0.240265  1.000000
# dis     -0.379670  0.664408 -0.708027 -0.099176 -0.769230  0.205246 -0.747881
# rad      0.625505 -0.311948  0.595129 -0.007368  0.611441 -0.209847  0.456022
# tax      0.582764 -0.314563  0.720760 -0.035587  0.668023 -0.292048  0.506456
# ptratio  0.289946 -0.391679  0.383248 -0.121515  0.188933 -0.355501  0.261515
# ...

# %%
sns.heatmap(Correlation_Boston,square=True,cmap='coolwarm')

# %%
Web_mon = [319,281,173,272,182,170,342,381,157,366]
Web_tues = [371,270,288,161,124,354,354,190,357,370]
WeeksOfMonth = ['W 1','W 2','W 3','W 4','W 5','W 6','W 7','W 8','W 9','W 10']
Website_data = pd.DataFrame({'Web_monday':Web_mon,'Web_tuesday':Web_tues})
Website_data
# Out:
#    Web_monday  Web_tuesday
# 0         319          371
# 1         281          270
# 2         173          288
# 3         272          161
# 4         182          124
# 5         170          354
# 6         342          354
# 7         381          190
# 8         157          357
# 9         366          370

# %%
sns.pairplot(Website_data)
