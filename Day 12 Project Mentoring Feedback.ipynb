# %%
# Q1 - Import data into Python environment.
import pandas as pd
Telecom = pd.read_csv("/home/labsuser//Datasets/Comcast_telecom_complaints_data.csv")
Telecom
# Out:
#      Ticket #                                 Customer Complaint      Date  \
# 0      250635                      Comcast Cable Internet Speeds  22-04-15
# 1      223441       Payment disappear - service got disconnected  04-08-15
# 2      242732                                  Speed and Service  18-04-15
# 3      277946  Comcast Imposed a New Usage Cap of 300GB that ...  05-07-15
# 4      307175         Comcast not working and no service to boot  26-05-15
# ...       ...                                                ...       ...
# 2219   213550                               Service Availability  04-02-15
# 2220   318775         Comcast Monthly Billing for Returned Modem  06-02-15
# 2221   331188                            complaint about comcast  06-09-15
# 2222   360489             Extremely unsatisfied Comcast customer  23-06-15
# 2223   363614               Comcast, Ypsilanti MI Internet Speed  24-06-15
#
#      Date_month_year         Time        Received Via        City     State  \
# 0          22-Apr-15   3:53:50 PM  Customer Care Call    Abingdon  Maryland
# 1          04-Aug-15  10:22:56 AM            Internet     Acworth   Georgia
# 2          18-Apr-15   9:55:47 AM            Internet     Acworth   Georgia
# 3          05-Jul-15  11:59:35 AM            Internet     Acworth   Georgia
# 4          26-May-15   1:25:26 PM            Internet     Acworth   Georgia
# ...              ...          ...                 ...         ...       ...
# 2219       04-Feb-15   9:13:18 AM  Customer Care Call  Youngstown   Florida
# 2220       06-Feb-15   1:24:39 PM  Customer Care Call   Ypsilanti  Michigan
# 2221       06-Sep-15   5:28:41 PM            Internet   Ypsilanti  Michigan
# 2222       23-Jun-15  11:13:30 PM  Customer Care Call   Ypsilanti  Michigan
# 2223       24-Jun-15  10:28:33 PM  Customer Care Call   Ypsilanti  Michigan
#
#       Zip code  Status Filing on Behalf of Someone
# 0        21009  Closed                          No
# 1        30102  Closed                          No
# 2        30101  Closed                         Yes
# 3        30101    Open                         Yes
# 4        30101  Solved                          No
# ...        ...     ...                         ...
# 2219     32466  Closed                          No
# 2220     48197  Solved                          No
# 2221     48197  Solved                          No
# 2222     48197  Solved                          No
# 2223     48198    Open                         Yes
#
# [2224 rows x 11 columns]

# %%
# Q2 - Provide the trend chart for the number of complaints at monthly and daily granularity levels.
## part 1 at date level
DataforTrendChart = Telecom.groupby('Date')['Date'].agg(len)
DataforTrendChart
type(DataforTrendChart)
DFforTrendChart = pd.DataFrame(DataforTrendChart)
DFforTrendChart.columns=['Freq']
DFforTrendChart
# Out:
#             Freq
# Date
# 2015-01-04    18
# 2015-01-05    12
# 2015-01-06    25
# 2015-02-04    27
# 2015-02-05     7
# ...          ...
# 2015-11-05    12
# 2015-11-06    21
# 2015-12-04    15
# 2015-12-05     7
# 2015-12-06    43
#
# [91 rows x 1 columns]

# %%
import matplotlib.pyplot as plt
plt.plot(DFforTrendChart.Freq)
plt.show()

# %%
#Part II at month level
Telecom.Date.dtype
import datetime
Telecom['Date'] = pd.to_datetime(Telecom.Date, format="%d-%m-%y")
Telecom['Month'] = Telecom['Date'].dt.month
 
DataforTrendChart = Telecom.groupby('Month')['Month'].agg(len)
DataforTrendChart
type(DataforTrendChart)
DFforTrendChart = pd.DataFrame(DataforTrendChart)
plt.plot(DFforTrendChart.Month)
plt.show()

# %%
#Q3 - - Provide a table with the frequency of complaint types.
pd.value_counts(Telecom['Customer Complaint'])
# Out:
# Comcast                                                                               83
# Comcast Internet                                                                      18
# Comcast Data Cap                                                                      17
# comcast                                                                               13
# Comcast Data Caps                                                                     11
#                                                                                       ..
# Comcast overbilled me and added numerous hidden charges                                1
# Overcharge/ promo end                                                                  1
# Comcast Downgraded service with no notification                                        1
# Comcast internet speeds                                                                1
# Comcast speeds as low as 12 MB/s, paying for 105 MB/s and they wont figure it out.     1
# Name: Customer Complaint, Length: 1841, dtype: int64

# %%
#Q 4 - Create a new categorical variable with value as Open and Closed. Open & Pending is to be categorized as Open and Closed & Solved is to be categorized as Closed.
Telecom.Status.unique()
Telecom['Status_New'] = Telecom['Status'].map({'Open':'Open','Closed':'close','Solved':'close','Pending':'Open'})

# %%
Q5 = Telecom.groupby(['State','Status_New'])['Status_New'].agg(len)
type(Q5)
Q5 = pd.DataFrame(Q5)
 
Q5_renamed = Q5.rename(columns={'Status_New':"Freq"})
 
Q5_1  = Q5_renamed.reset_index()
type(Q5_1)
Q5_1
# Out:
#             State Status_New  Freq
# 0         Alabama       Open     9
# 1         Alabama      close    17
# 2         Arizona       Open     6
# 3         Arizona      close    14
# 4        Arkansas      close     6
# ..            ...        ...   ...
# 72       Virginia      close    49
# 73     Washington       Open    23
# 74     Washington      close    75
# 75  West Virginia       Open     3
# 76  West Virginia      close     8
#
# [77 rows x 3 columns]

# %%
Q5_1_subset = Q5_1
Q5_1_subset_open = Q5_1_subset.query("Status_New == 'Open'")
Q5_1_subset_close = Q5_1_subset.query("Status_New == 'close'")
Q5_1_subset_open
# Out:
#                    State Status_New  Freq
# 0                Alabama       Open     9
# 2                Arizona       Open     6
# 5             California       Open    61
# 7               Colorado       Open    22
# 9            Connecticut       Open     3
# 11              Delaware       Open     4
# 13  District Of Columbia       Open     2
# 16               Florida       Open    39
# 18               Georgia       Open    80
# 20              Illinois       Open    29
# 22               Indiana       Open     9
# 25                Kansas       Open     1
# 27              Kentucky       Open     3
# 29             Louisiana       Open     1
# 31                 Maine       Open     2
# 33              Maryland       Open    15
# 35         Massachusetts       Open    11
# 37              Michigan       Open    23
# 39             Minnesota       Open     4
# 41           Mississippi       Open    16
# 43              Missouri       Open     1
# 47         New Hampshire       Open     4
# 49            New Jersey       Open    19
# 51            New Mexico       Open     4
# 56                Oregon       Open    13
# 58          Pennsylvania       Open    20
# 61        South Carolina       Open     3
# 63             Tennessee       Open    47
# 65                 Texas       Open    22
# 67                  Utah       Open     6
# 69               Vermont       Open     1
# 71              Virginia       Open    11
# 73            Washington       Open    23
# 75         West Virginia       Open     3

# %%
Q5_1_subset_close
# Out:
#                    State Status_New  Freq
# 1                Alabama      close    17
# 3                Arizona      close    14
# 4               Arkansas      close     6
# 6             California      close   159
# 8               Colorado      close    58
# 10           Connecticut      close     9
# 12              Delaware      close     8
# 14  District Of Columbia      close    14
# 15  District of Columbia      close     1
# 17               Florida      close   201
# 19               Georgia      close   208
# 21              Illinois      close   135
# 23               Indiana      close    50
# 24                  Iowa      close     1
# 26                Kansas      close     1
# 28              Kentucky      close     4
# 30             Louisiana      close    12
# 32                 Maine      close     3
# 34              Maryland      close    63
# 36         Massachusetts      close    50
# 38              Michigan      close    92
# 40             Minnesota      close    29
# 42           Mississippi      close    23
# 44              Missouri      close     3
# 45               Montana      close     1
# 46                Nevada      close     1
# 48         New Hampshire      close     8
# 50            New Jersey      close    56
# 52            New Mexico      close    11
# 53              New York      close     6
# 54        North Carolina      close     3
# 55                  Ohio      close     3
# 57                Oregon      close    36
# 59          Pennsylvania      close   110
# 60          Rhode Island      close     1
# 62        South Carolina      close    15
# 64             Tennessee      close    96
# 66                 Texas      close    49
# 68                  Utah      close    16
# 70               Vermont      close     2
# 72              Virginia      close    49
# 74            Washington      close    75
# 76         West Virginia      close     8

# %%
Q5_Final = pd.concat([Q5_1_subset_open.set_index('State').rename(columns={'Freq':'Open'}).drop('Status_New',axis=1),
           Q5_1_subset_close.set_index('State').rename(columns={'Freq':'Close'}).drop('Status_New',axis=1)],axis=1)
Q5_Final
# Out:
#                       Open  Close
# Alabama                9.0     17
# Arizona                6.0     14
# California            61.0    159
# Colorado              22.0     58
# Connecticut            3.0      9
# Delaware               4.0      8
# District Of Columbia   2.0     14
# Florida               39.0    201
# Georgia               80.0    208
# Illinois              29.0    135
# Indiana                9.0     50
# Kansas                 1.0      1
# Kentucky               3.0      4
# Louisiana              1.0     12
# Maine                  2.0      3
# Maryland              15.0     63
# Massachusetts         11.0     50
# Michigan              23.0     92
# Minnesota              4.0     29
# Mississippi           16.0     23
# Missouri               1.0      3
# New Hampshire          4.0      8
# New Jersey            19.0     56
# New Mexico             4.0     11
# Oregon                13.0     36
# Pennsylvania          20.0    110
# South Carolina         3.0     15
# Tennessee             47.0     96
# Texas                 22.0     49
# Utah                   6.0     16
# Vermont                1.0      2
# Virginia              11.0     49
# Washington            23.0     75
# West Virginia          3.0      8
# Arkansas               NaN      6
# District of Columbia   NaN      1
# Iowa                   NaN      1
# Montana                NaN      1
# Nevada                 NaN      1
# New York               NaN      6
# North Carolina         NaN      3
# Ohio                   NaN      3
# Rhode Island           NaN      1

# %%
plt.figure(figsize=(20,8))
plt.bar(Q5_Final.index ,Q5_Final.Open,color='red')
plt.bar(Q5_Final.index ,Q5_Final.Close, bottom =Q5_Final.Open,color='green')
plt.xticks(rotation=90)
plt.show()

# %%
# Q5 (insights) - Which state has the highest percentage of unresolved complaints
Unsolved_c = pd.crosstab(Telecom.State,Telecom.Status_New)
type(Unsolved_c)
Unsolved_c['Unsolved_pct'] = Unsolved_c.Open/(Unsolved_c.Open+Unsolved_c.close)
Unsolved_c
Unsolved_c.sort_values(['Unsolved_pct'],ascending=False).iloc[0,:]
Unsolved_c
# Out:
# Status_New            Open  close  Unsolved_pct
# State
# Alabama                  9     17      0.346154
# Arizona                  6     14      0.300000
# Arkansas                 0      6      0.000000
# California              61    159      0.277273
# Colorado                22     58      0.275000
# Connecticut              3      9      0.250000
# Delaware                 4      8      0.333333
# District Of Columbia     2     14      0.125000
# District of Columbia     0      1      0.000000
# Florida                 39    201      0.162500
# Georgia                 80    208      0.277778
# Illinois                29    135      0.176829
# Indiana                  9     50      0.152542
# Iowa                     0      1      0.000000
# Kansas                   1      1      0.500000
# Kentucky                 3      4      0.428571
# Louisiana                1     12      0.076923
# Maine                    2      3      0.400000
# Maryland                15     63      0.192308
# Massachusetts           11     50      0.180328
# Michigan                23     92      0.200000
# Minnesota                4     29      0.121212
# Mississippi             16     23      0.410256
# Missouri                 1      3      0.250000
# Montana                  0      1      0.000000
# Nevada                   0      1      0.000000
# New Hampshire            4      8      0.333333
# New Jersey              19     56      0.253333
# New Mexico               4     11      0.266667
# New York                 0      6      0.000000
# North Carolina           0      3      0.000000
# Ohio                     0      3      0.000000
# Oregon                  13     36      0.265306
# Pennsylvania            20    110      0.153846
# Rhode Island             0      1      0.000000
# South Carolina           3     15      0.166667
# Tennessee               47     96      0.328671
# Texas                   22     49      0.309859
# Utah                     6     16      0.272727
# Vermont                  1      2      0.333333
# Virginia                11     49      0.183333
# Washington              23     75      0.234694
# West Virginia            3      8      0.272727

# %%
# use case scenario of using a find function. This can be used for categorizing the complaint type in the comcast project
import pandas as pd
Emp1= pd.DataFrame({"Name":["John-Smith","Angel-Brown"],"Age":[34,32]})
Emp1
Emp1['Position_of_Dlm']= Emp1['Name'].str.find("Smith")
Emp1
# Out:
#           Name  Age  Position_of_Dlm
# 0   John-Smith   34                5
# 1  Angel-Brown   32               -1

# %%
ca_house = pd.read_excel("/home/labsuser//Datasets/California_housing.xlsx")
ca_house
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                  41          880           129.0
# 1        -122.22     37.86                  21         7099          1106.0
# 2        -122.24     37.85                  52         1467           190.0
# 3        -122.25     37.85                  52         1274           235.0
# 4        -122.25     37.85                  52         1627           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                  25         1665           374.0
# 20636    -121.21     39.49                  18          697           150.0
# 20637    -121.22     39.43                  17         2254           485.0
# 20638    -121.32     39.43                  18         1860           409.0
# 20639    -121.24     39.37                  16         2785           616.0
#
#        population  households  median_income ocean_proximity  \
# 0             322         126         8.3252        NEAR BAY
# 1            2401        1138         8.3014        NEAR BAY
# 2             496         177         7.2574        NEAR BAY
# 3             558         219         5.6431        NEAR BAY
# 4             565         259         3.8462        NEAR BAY
# ...           ...         ...            ...             ...
# 20635         845         330         1.5603          INLAND
# 20636         356         114         2.5568          INLAND
# 20637        1007         433         1.7000          INLAND
# 20638         741         349         1.8672          INLAND
# 20639        1387         530         2.3886          INLAND
#
#        median_house_value
# 0                  452600
# 1                  358500
# 2                  352100
# 3                  341300
# 4                  342200
# ...                   ...
# 20635               78100
# 20636               77100
# 20637               92300
# 20638               84700
# 20639               89400
#
# [20640 rows x 10 columns]

# %%
ca_house.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20640 non-null  float64
#  1   latitude            20640 non-null  float64
#  2   housing_median_age  20640 non-null  int64
#  3   total_rooms         20640 non-null  int64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20640 non-null  int64
#  6   households          20640 non-null  int64
#  7   median_income       20640 non-null  float64
#  8   ocean_proximity     20640 non-null  object
#  9   median_house_value  20640 non-null  int64
# dtypes: float64(4), int64(5), object(1)
# memory usage: 1.6+ MB

# %%
import numpy as np
transformed_price = np.log(ca_house.median_house_value)
transformed_price = pd.DataFrame(transformed_price)
transformed_price.columns = ['Log_transformed']
transformed_price
# Out:
#        Log_transformed
# 0            13.022764
# 1            12.789684
# 2            12.771671
# 3            12.740517
# 4            12.743151
# ...                ...
# 20635        11.265745
# 20636        11.252859
# 20637        11.432799
# 20638        11.346871
# 20639        11.400876
#
# [20640 rows x 1 columns]

# %%
ca_house1 = pd.concat([ca_house,transformed_price],axis=1)
ca_house1
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                  41          880           129.0
# 1        -122.22     37.86                  21         7099          1106.0
# 2        -122.24     37.85                  52         1467           190.0
# 3        -122.25     37.85                  52         1274           235.0
# 4        -122.25     37.85                  52         1627           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                  25         1665           374.0
# 20636    -121.21     39.49                  18          697           150.0
# 20637    -121.22     39.43                  17         2254           485.0
# 20638    -121.32     39.43                  18         1860           409.0
# 20639    -121.24     39.37                  16         2785           616.0
#
#        population  households  median_income ocean_proximity  \
# 0             322         126         8.3252        NEAR BAY
# 1            2401        1138         8.3014        NEAR BAY
# 2             496         177         7.2574        NEAR BAY
# 3             558         219         5.6431        NEAR BAY
# 4             565         259         3.8462        NEAR BAY
# ...           ...         ...            ...             ...
# 20635         845         330         1.5603          INLAND
# 20636         356         114         2.5568          INLAND
# 20637        1007         433         1.7000          INLAND
# 20638         741         349         1.8672          INLAND
# 20639        1387         530         2.3886          INLAND
#
#        median_house_value  Log_transformed
# 0                  452600        13.022764
# 1                  358500        12.789684
# 2                  352100        12.771671
# 3                  341300        12.740517
# 4                  342200        12.743151
# ...                   ...              ...
# 20635               78100        11.265745
# 20636               77100        11.252859
# 20637               92300        11.432799
# 20638               84700        11.346871
# 20639               89400        11.400876
#
# [20640 rows x 11 columns]

# %%
from sklearn.linear_model import LinearRegression
lm = LinearRegression()
lm_model = lm.fit(pd.DataFrame(ca_house1.median_income),ca_house1.Log_transformed)
lm_model
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
lm_model.intercept_
# Out:
# 11.321403126932864

# %%
lm_model.coef_
# Out:
# array([0.19724773])

# %%
predicted_log = lm_model.predict(pd.DataFrame(ca_house1.median_income))
predicted_log
# Out:
# array([12.96352991, 12.95883541, 12.75290878, ..., 11.65672426,
#        11.68970408, 11.79254905])

# %%
np.exp(predicted_log)
# Out:
# array([426569.20977667, 424571.3754474 , 345555.58198452, ...,
#        115465.17674082, 119336.68744668, 132263.18581398])

# %%
pd.concat([ca_house1,pd.DataFrame(np.exp(predicted_log))],axis=1)
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                  41          880           129.0
# 1        -122.22     37.86                  21         7099          1106.0
# 2        -122.24     37.85                  52         1467           190.0
# 3        -122.25     37.85                  52         1274           235.0
# 4        -122.25     37.85                  52         1627           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                  25         1665           374.0
# 20636    -121.21     39.49                  18          697           150.0
# 20637    -121.22     39.43                  17         2254           485.0
# 20638    -121.32     39.43                  18         1860           409.0
# 20639    -121.24     39.37                  16         2785           616.0
#
#        population  households  median_income ocean_proximity  \
# 0             322         126         8.3252        NEAR BAY
# 1            2401        1138         8.3014        NEAR BAY
# 2             496         177         7.2574        NEAR BAY
# 3             558         219         5.6431        NEAR BAY
# 4             565         259         3.8462        NEAR BAY
# ...           ...         ...            ...             ...
# 20635         845         330         1.5603          INLAND
# 20636         356         114         2.5568          INLAND
# 20637        1007         433         1.7000          INLAND
# 20638         741         349         1.8672          INLAND
# 20639        1387         530         2.3886          INLAND
#
#        median_house_value  Log_transformed              0
# 0                  452600        13.022764  426569.209777
# 1                  358500        12.789684  424571.375447
# 2                  352100        12.771671  345555.581985
# 3                  341300        12.740517  251322.380149
# 4                  342200        12.743151  176320.269923
# ...                   ...              ...            ...
# 20635               78100        11.265745  112326.912008
# 20636               77100        11.252859  136724.894444
# 20637               92300        11.432799  115465.176741
# 20638               84700        11.346871  119336.687447
# 20639               89400        11.400876  132263.185814
#
# [20640 rows x 12 columns]

# %%
ca_house1.median_income.skew()
# Out:
# 1.6466567021344465

# %%
from scipy.stats import kurtosis
kurtosis(ca_house1.median_income)
# Out:
# 4.951033760409659

# %%
from scipy.stats import norm
norm.cdf(4,np.mean(ca_house1.median_income),np.std(ca_house1.median_income))
# 52% people have income higher than 4000$
# Out:
# 0.5271374044905052

# %%
Default = pd.read_csv("/home/labsuser//Datasets/Default_On_Payment - ML.csv")
Default
# Out:
#        Customer_ID Status_Checking_Acc  Duration_in_Months Credit_History  \
# 0           100015                 A14                  27            A32
# 1           100031                 A11                  12            A34
# 2           100046                 A12                  13            A34
# 3           100103                 A14                  24            A32
# 4           100104                 A11                  24            A32
# ...            ...                 ...                 ...            ...
# 39995       999893                 A14                  21            A33
# 39996       999911                 A14                   9            A32
# 39997       999928                 A12                  13            A34
# 39998       999946                 A12                  45            A34
# 39999       999961                 A11                  48            A32
#
#       Purposre_Credit_Taken  Credit_Amount Savings_Acc  \
# 0                       A40           2570         A61
# 1                       A43            385         A61
# 2                       A43            882         A61
# 3                       A40           1393         A61
# 4                       A40           3123         A61
# ...                     ...            ...         ...
# 39995                   A41           2993         A61
# 39996                   A42           1388         A61
# 39997                   A43            882         A61
# 39998                   A43           4746         A61
# 39999                   A43           6758         A61
#
#       Years_At_Present_Employment  Inst_Rt_Income Marital_Status_Gender  ...  \
# 0                             A73               3                   A92  ...
# 1                             A74               4                   A92  ...
# 2                             A72               4                   A93  ...
# 3                             A73               2                   A93  ...
# 4                             A72               4                   A92  ...
# ...                           ...             ...                   ...  ...
# 39995                         A73               3                   A93  ...
# 39996                         A73               4                   A92  ...
# 39997                         A72               4                   A93  ...
# 39998                         A72               4                   A93  ...
# 39999                         A73               3                   A92  ...
#
#       Property  Age Other_Inst_Plans   Housing Num_CC   Job  Dependents  \
# 0         A121   21              A143     A151      1  A173           1
# 1         A121   58              A143     A152      4  A172           1
# 2         A121   23              A143     A152      2  A173           1
# 3         A121   31              A143     A152      1  A173           1
# 4         A122   27              A143     A152      1  A173           1
# ...        ...  ...               ...      ...    ...   ...         ...
# 39995     A121   28              A142     A152      2  A172           1
# 39996     A121   26              A143     A151      1  A173           1
# 39997     A121   23              A143     A152      2  A173           1
# 39998     A122   25              A143     A152      2  A172           1
# 39999     A123   31              A143     A152      1  A173           1
#
#       Telephone  Foreign_Worker Default_On_Payment
# 0          A191            A201                  1
# 1          A192            A201                  0
# 2          A191            A201                  0
# 3          A192            A201                  0
# 4          A191            A201                  1
# ...         ...             ...                ...
# 39995      A191            A201                  0
# 39996      A191            A201                  0
# 39997      A191            A201                  0
# 39998      A191            A201                  1
# 39999      A192            A201                  1
#
# [40000 rows x 22 columns]

# %%
Cross_grid_fw = pd.crosstab(Default.Foreign_Worker,Default.Default_On_Payment)
Cross_grid_fw
# Out:
# Default_On_Payment      0      1
# Foreign_Worker
# A201                26720  11800
# A202                 1320    160

# %%
# statistical significance
# Null hypothesis - No relation of Foreign worker status with PD Ha = Relation exists
import scipy
scipy.stats.chi2_contingency(Cross_grid_fw)
# Out:
# (266.2457032281066,
#  7.467285344517469e-60,
#  1,
#  array([[27002.52, 11517.48],
#         [ 1037.48,   442.52]]))
